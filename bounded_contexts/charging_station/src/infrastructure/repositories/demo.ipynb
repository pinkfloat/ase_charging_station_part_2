# %%
import pandas as pd

# %%
from pathlib import Path
import pandas as pd

# Get the absolute path of the CSV file
csv_path = Path(__file__).resolve().parent.parent.parent / "infrastructure" / "data" / "ChargingStationData.csv"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 5
#       2 import pandas as pd
#       4 # Get the absolute path of the CSV file
# ----> 5 csv_path = Path(__file__).resolve().parent.parent.parent / "infrastructure" / "data" / "ChargingStationData.csv"
#
# NameError: name '__file__' is not defined

# %%
df = pd.read_csv(r'.\src\infrastructure\data\ChargingStationData.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df = pd.read_csv(r'.\src\infrastructure\data\ChargingStationData.csv')
#
# File d:\ase-2\ase-env\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
from pathlib import Path
import pandas as pd  # or csv module

# Get path relative to current file location
current_dir = Path(__file__).parent
csv_path = current_dir / "../../../infrastructure/data/ChargingStationData.csv"

# Resolve to absolute path and read
absolute_path = csv_path.resolve()
df = pd.read_csv(absolute_path)  # Using pandas
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 5
#       2 import pandas as pd  # or csv module
#       4 # Get path relative to current file location
# ----> 5 current_dir = Path(__file__).parent
#       6 csv_path = current_dir / "../../../infrastructure/data/ChargingStationData.csv"
#       8 # Resolve to absolute path and read
#
# NameError: name '__file__' is not defined

# %%
import pandas as pd

# Navigate up to the src directory and then down to infrastructure/data
df = pd.read_csv(r'bounded_contexts\charging_station\src\infrastructure\data\ChargingStationData.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 4
#       1 import pandas as pd
#       3 # Navigate up to the src directory and then down to infrastructure/data
# ----> 4 df = pd.read_csv(r'bounded_contexts\charging_station\src\infrastructure\data\ChargingStationData.csv')
#
# ...

# %%
df
# Out:
#                                stationOperator  \
# 0     Berliner Stadtwerke KommunalPartner GmbH
# 1     Berliner Stadtwerke KommunalPartner GmbH
# 2               E.ON Drive Infrastructure GmbH
# 3               E.ON Drive Infrastructure GmbH
# 4               E.ON Drive Infrastructure GmbH
# ...                                        ...
# 2873  Berliner Stadtwerke KommunalPartner GmbH
# 2874  Berliner Stadtwerke KommunalPartner GmbH
# 2875  Berliner Stadtwerke KommunalPartner GmbH
# 2876  Berliner Stadtwerke KommunalPartner GmbH
# 2877            E.ON Drive Infrastructure GmbH
#
#                                    stationName    PLZ Bundesland   Latitude  \
# 0     Berliner Stadtwerke KommunalPartner GmbH  10117     Berlin  52.511150
# 1     Berliner Stadtwerke KommunalPartner GmbH  10117     Berlin  52.513083
# 2                    E.ON Drive Infrastructure  10117     Berlin  52.515659
# 3                    E.ON Drive Infrastructure  10117     Berlin  52.518970
# ...
